# %% [markdown]
# # Mask RCNN Nucleus

# %% [markdown]
# ## Repro [Github](https://github.com/akTwelve/Mask_RCNN)

# %%
#!git clone https://github.com/matterport/Mask_RCNN # TF1.1x
# !git clone https://github.com/akTwelve/Mask_RCNN  # TF2.x
# %cd Mask_RCNN

# %%
#!pip install -q tensorflow==1.15.0
#!pip install -q keras==2.0.8
# !pip install -q pycocotools

# %% [markdown]
# ### Download Dataset

# %%
# !mkdir -p datasets/nucleus/stage1_train
# %cd datasets/nucleus/stage1_train
# !unzip /kaggle/input/data-science-bowl-2018/stage1_train.zip
# %cd ../../..

# %%
# !mkdir -p datasets/nucleus/val
# %cd datasets/nucleus/val
# !unzip /kaggle/input/data-science-bowl-2018/stage1_test.zip
# %cd ../../..

# %% [markdown]
# ### Download pre-trained COCO weights

# %%
## download pre-trained COCO weights
# !wget https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5

# %% [markdown]
# ## Train Model for Nucleus

# %%
# %cd samples/nucleus

# %%
# !python nucleus.py train --dataset ../../datasets/nucleus --weights='coco' --subset 'train'

# %% [markdown]
# #### *Take a long time for generating augmentation to start epochs,*
# #### *Then train 20 epochs at heads, and train 40 epochs at all layers.*
