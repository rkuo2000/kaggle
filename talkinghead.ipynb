# %% [markdown]
# # Realistic-Neural-Talking-Head-Models

# %% [markdown]
# ## [Paper](https://arxiv.org/pdf/1905.08233.pdf)
# ## [Github](https://github.com/vincent-thevenin/Realistic-Neural-Talking-Head-Models)
# ## [VoxCeleb2 Dataset](http://www.robots.ox.ac.uk/~vgg/data/voxceleb/vox2.html)
# ### to train VGGFace

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Apporach
# ![image.png](attachment:image.png)

# %% [markdown]
# [pretrained weights](https://drive.google.com/open?id=1vdFz4sh23hC_KIQGJjwbTfUdPG-aYor8)
