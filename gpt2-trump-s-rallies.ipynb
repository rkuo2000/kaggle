# %% [markdown]
# # GPT-2 finetune for Donald Trump's Rallies

# %% [markdown]
# ## Repro [GPT-2-simple](https://github.com/minimaxir/gpt-2-simple)

# %%
# !git clone https://github.com/minimaxir/gpt-2-simple
# %cd gpt-2-simple

# %%
# !pip install -r requirements.txt

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ## download GPT2 pretrained model

# %%
import os
import glob
import requests
import gpt_2_simple as gpt2

# %%
model_name = "124M" # Small model
if not os.path.isdir(os.path.join("models", model_name)):
    print(f"Downloading {model_name} model...")
    gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/

# %% [markdown]
# ## gether Donald Trump's Rallies

# %%
filepath = "/kaggle/input/donald-trumps-rallies/"
for f in glob.glob(filepath+"*.txt"):
    os.system("cat "+f+" >> DonalTrumpRallies.txt")

# %% [markdown]
# ## Finetune GPT2

# %%
file_name = "DonalTrumpRallies.txt"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              steps=100)   # steps is max number of training steps

# %% [markdown]
# ## Generate Text

# %%
gpt2.generate(sess)
